# %% [markdown]
# - Introduction to Pandas
# - DataFrame & Series
# - Creating DataFrame from Scratch (Post-read)
# - Basic ops on a DataFrame
# - Basic ops on Columns
#     - Accessing column(s)
#     - Check for unique values
#     - Rename column
#     - Deleting column(s)
#     - Creating new column(s)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Problem Statement
#
# - Imagine that you are a Data Scientist with McKinsey.
# - McKinsey wants to understand the relation between GDP per capita and life expectancy for their clients.
# - The company has obtained data from various surveys conducted in different countries over several years.
# - The acquired data includes information on
#   - Country
#   - Population Size
#   - Life Expectancy
#   - GDP per Capita
# - We have to analyse the data and draw inferences that are meaningful to the company.

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2025-01-24 10:10:58--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 142.250.98.101, 142.250.98.139, 142.250.98.113, ...
# Connecting to drive.google.com (drive.google.com)|142.250.98.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2025-01-24 10:10:58--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.216.132, 2607:f8b0:400c:c12::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.216.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
df=pd.read_csv('mckinsey.csv')

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.tail()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df.tail(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1694  Zimbabwe  1962     4277736    Africa    52.358  527.272182
# 1695  Zimbabwe  1967     4995432    Africa    53.995  569.795071
# 1696  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df[['country','year']].head()
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967
# 4  Afghanistan  1972

# %%
df[['country','year','gdp_cap']].head()
# Out:
#        country  year     gdp_cap
# 0  Afghanistan  1952  779.445314
# 1  Afghanistan  1957  820.853030
# 2  Afghanistan  1962  853.100710
# 3  Afghanistan  1967  836.197138
# 4  Afghanistan  1972  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.shape
# Out:
# (1704, 6)

# %%
df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
df['country'].nunique()
# Out:
# 142

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['continent'].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename({'country':'Country'},axis=1,inplace=True)

# %%
df.head()
# Out:
#        Country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename({'year':'yrs'},axis=1,inplace=True)

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop('yrs',axis=1)
# Out:
#           Country  population continent  life_exp     gdp_cap
# 0     Afghanistan     8425333      Asia    28.801  779.445314
# 1     Afghanistan     9240934      Asia    30.332  820.853030
# 2     Afghanistan    10267083      Asia    31.997  853.100710
# 3     Afghanistan    11537966      Asia    34.020  836.197138
# 4     Afghanistan    13079460      Asia    36.088  739.981106
# ...           ...         ...       ...       ...         ...
# 1699     Zimbabwe     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe    12311143    Africa    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df
# Out:
#           Country   yrs  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['per_capita_income']=df['gdp_cap']/df['population']

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#    per_capita_income
# 0           0.000093
# 1           0.000089
# 2           0.000083
# 3           0.000072
# 4           0.000057

# %%
df.drop('per_capita_income',axis=1, inplace=True)

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df['gdp'] = df['population'] * df['gdp_cap']

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856e+09
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014e+09
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553e+09

# %%
df.shape
# Out:
# (1704, 7)

# %%
df['new'] = [i for i in range(1704)]

# %%
df
# Out:
#           Country   yrs  population continent  life_exp     gdp_cap  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#                gdp   new
# 0     6.567086e+09     0
# 1     7.585449e+09     1
# 2     8.758856e+09     2
# 3     9.648014e+09     3
# ...

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap  \
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
#
#             gdp  new
# 0  6.567086e+09    0
# 1  7.585449e+09    1
# 2  8.758856e+09    2
# 3  9.648014e+09    3
# 4  9.678553e+09    4

# %%
df.drop('new',axis=1,inplace=True)

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap           gdp
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314  6.567086e+09
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030  7.585449e+09
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710  8.758856e+09
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138  9.648014e+09
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106  9.678553e+09

# %%
df.drop('gdp',axis=1,inplace=True)

# %%
df.drop?

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[1705] = ['India',2020,1234556,'Asia',41.01,810.98]

# %%
df.loc[1706] = ['India',2020,1234556,'Asia',41.01,810.98]

# %%
df.tail()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705     India  2020     1234556      Asia    41.010  810.980000
# 1706     India  2020     1234556      Asia    41.010  810.980000

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(keep='first')
# Out:
#           Country   yrs  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1705        India  2020     1234556      Asia    41.010  810.980000
#
# [1705 rows x 6 columns]

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.sort_values(['population'],ascending=False)
# Out:
#                     Country   yrs  population continent  life_exp      gdp_cap
# 299                   China  2007  1318683096      Asia    72.961  4959.114854
# 298                   China  2002  1280400000      Asia    72.028  3119.280896
# 297                   China  1997  1230075000      Asia    70.426  2289.234136
# 296                   China  1992  1164970000      Asia    68.690  1655.784158
# 707                   India  2007  1110396331      Asia    64.698  2452.210407
# ...                     ...   ...         ...       ...       ...          ...
# 1299  Sao Tome and Principe  1967       70787    Africa    54.425  1384.840593
# 1298  Sao Tome and Principe  1962       65345    Africa    51.893  1071.551119
# 420                Djibouti  1952       63149    Africa    34.812  2669.529475
# 1297  Sao Tome and Principe  1957       61325    Africa    48.945   860.736903
# 1296  Sao Tome and Principe  1952       60011    Africa    46.471   879.583586
#
# [1706 rows x 6 columns]

# %%
df.sort_values(['population','life_exp'])
# Out:
#                     Country   yrs  population continent  life_exp      gdp_cap
# 1296  Sao Tome and Principe  1952       60011    Africa    46.471   879.583586
# 1297  Sao Tome and Principe  1957       61325    Africa    48.945   860.736903
# 420                Djibouti  1952       63149    Africa    34.812  2669.529475
# 1298  Sao Tome and Principe  1962       65345    Africa    51.893  1071.551119
# 1299  Sao Tome and Principe  1967       70787    Africa    54.425  1384.840593
# ...                     ...   ...         ...       ...       ...          ...
# 707                   India  2007  1110396331      Asia    64.698  2452.210407
# 296                   China  1992  1164970000      Asia    68.690  1655.784158
# 297                   China  1997  1230075000      Asia    70.426  2289.234136
# 298                   China  2002  1280400000      Asia    72.028  3119.280896
# 299                   China  2007  1318683096      Asia    72.961  4959.114854
#
# [1706 rows x 6 columns]

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[2]
# Out:
# Country       Afghanistan
# yrs                  1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# Country       Afghanistan
# yrs                  1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.index=list(range(1,df.shape[0]+1))

# %%
df.head()
# Out:
#        Country   yrs  population continent  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.reset_index(inplace=True)

# %%
df.iloc[2]
# Out:
# index                   3
# Country       Afghanistan
# yrs                  1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.loc[2]
# Out:
# index                   3
# Country       Afghanistan
# yrs                  1962
# population       10267083
# continent            Asia
# life_exp           31.997
# gdp_cap         853.10071
# Name: 2, dtype: object

# %%
df.shape[0]
# Out:
# 1706

# %%
sample=df.head()

# %%
sample.index=['a','b','c','d','e']

# %%
sample
# Out:
#    index      Country   yrs  population continent  life_exp     gdp_cap
# a      1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# b      2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# c      3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# d      4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# e      5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
sample.loc['a']
# Out:
# index                   1
# Country       Afghanistan
# yrs                  1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: a, dtype: object

# %%
df.head()
# Out:
#    index      Country   yrs  population continent  life_exp     gdp_cap
# 0      1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1      2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2      3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3      4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4      5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.set_index('Country')
# Out:
#              index   yrs  population continent  life_exp     gdp_cap
# Country
# Afghanistan      1  1952     8425333      Asia    28.801  779.445314
# Afghanistan      2  1957     9240934      Asia    30.332  820.853030
# Afghanistan      3  1962    10267083      Asia    31.997  853.100710
# Afghanistan      4  1967    11537966      Asia    34.020  836.197138
# Afghanistan      5  1972    13079460      Asia    36.088  739.981106
# ...            ...   ...         ...       ...       ...         ...
# Zimbabwe      1702  1997    11404948    Africa    46.809  792.449960
# Zimbabwe      1703  2002    11926563    Africa    39.989  672.038623
# Zimbabwe      1704  2007    12311143    Africa    43.487  469.709298
# India         1705  2020     1234556      Asia    41.010  810.980000
# India         1706  2020     1234556      Asia    41.010  810.980000
#
# [1706 rows x 6 columns]

# %%
df.reset_index(drop=True)
# Out:
#       index      Country   yrs  population continent  life_exp     gdp_cap
# 0         1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1         2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2         3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3         4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4         5  Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...     ...          ...   ...         ...       ...       ...         ...
# 1701   1702     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1704     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704   1705        India  2020     1234556      Asia    41.010  810.980000
# 1705   1706        India  2020     1234556      Asia    41.010  810.980000
#
# [1706 rows x 7 columns]

# %%
df.iloc[0]
# Out:
# index                   1
# Country       Afghanistan
# yrs                  1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap        779.445314
# Name: 0, dtype: object

# %%
df[2:3]
# Out:
#    index      Country   yrs  population continent  life_exp    gdp_cap
# 2      3  Afghanistan  1962    10267083      Asia    31.997  853.10071

# %%
df[1:5]
# Out:
#    index      Country   yrs  population continent  life_exp     gdp_cap
# 1      2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2      3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3      4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4      5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#    index      Country   yrs  population continent  life_exp     gdp_cap
# 0      1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1      2  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2      3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3      4  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4      5  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[:, 2:4]
# Out:
#        yrs  population
# 0     1952     8425333
# 1     1957     9240934
# 2     1962    10267083
# 3     1967    11537966
# 4     1972    13079460
# ...    ...         ...
# 1701  1997    11404948
# 1702  2002    11926563
# 1703  2007    12311143
# 1704  2020     1234556
# 1705  2020     1234556
#
# [1706 rows x 2 columns]

# %%
df.iloc[::2]
# Out:
#       index      Country   yrs  population continent  life_exp     gdp_cap
# 0         1  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 2         3  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4         5  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 6         7  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 8         9  Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...     ...          ...   ...         ...       ...       ...         ...
# 1696   1697     Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1698   1699     Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1700   1701     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1702   1703     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1704   1705        India  2020     1234556      Asia    41.010  810.980000
#
# [853 rows x 7 columns]

# %%
df.tail(10)
# Out:
#       index   Country   yrs  population continent  life_exp     gdp_cap
# 1696   1697  Zimbabwe  1972     5861135    Africa    55.635  799.362176
# 1697   1698  Zimbabwe  1977     6642107    Africa    57.674  685.587682
# 1698   1699  Zimbabwe  1982     7636524    Africa    60.363  788.855041
# 1699   1700  Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700   1701  Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701   1702  Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702   1703  Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703   1704  Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704   1705     India  2020     1234556      Asia    41.010  810.980000
# 1705   1706     India  2020     1234556      Asia    41.010  810.980000

# %%
df.reset_index()
# Out:
#       level_0  index      Country   yrs  population continent  life_exp  \
# 0           0      1  Afghanistan  1952     8425333      Asia    28.801
# 1           1      2  Afghanistan  1957     9240934      Asia    30.332
# 2           2      3  Afghanistan  1962    10267083      Asia    31.997
# 3           3      4  Afghanistan  1967    11537966      Asia    34.020
# 4           4      5  Afghanistan  1972    13079460      Asia    36.088
# ...       ...    ...          ...   ...         ...       ...       ...
# 1701     1701   1702     Zimbabwe  1997    11404948    Africa    46.809
# 1702     1702   1703     Zimbabwe  2002    11926563    Africa    39.989
# 1703     1703   1704     Zimbabwe  2007    12311143    Africa    43.487
# 1704     1704   1705        India  2020     1234556      Asia    41.010
# 1705     1705   1706        India  2020     1234556      Asia    41.010
#
#          gdp_cap
# 0     779.445314
# 1     820.853030
# 2     853.100710
# 3     836.197138
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
# 2        2      3  Afghanistan  1962    10267083      Asia    31.997
# 3        3      4  Afghanistan  1967    11537966      Asia    34.020
# 4        4      5  Afghanistan  1972    13079460      Asia    36.088
#
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106

# %%
df.tail(10)
# Out:
#       level_0  index   Country   yrs  population continent  life_exp  \
# 1696     1696   1697  Zimbabwe  1972     5861135    Africa    55.635
# 1697     1697   1698  Zimbabwe  1977     6642107    Africa    57.674
# 1698     1698   1699  Zimbabwe  1982     7636524    Africa    60.363
# 1699     1699   1700  Zimbabwe  1987     9216418    Africa    62.351
# 1700     1700   1701  Zimbabwe  1992    10704340    Africa    60.377
# 1701     1701   1702  Zimbabwe  1997    11404948    Africa    46.809
# 1702     1702   1703  Zimbabwe  2002    11926563    Africa    39.989
# 1703     1703   1704  Zimbabwe  2007    12311143    Africa    43.487
# 1704     1704   1705     India  2020     1234556      Asia    41.010
# 1705     1705   1706     India  2020     1234556      Asia    41.010
#
#          gdp_cap
# 1696  799.362176
# 1697  685.587682
# 1698  788.855041
# 1699  706.157306
# 1700  693.420786
# 1701  792.449960
# 1702  672.038623
# 1703  469.709298
# 1704  810.980000
# 1705  810.980000

# %%
df.iloc[1697:,3:]
# Out:
#        yrs  population continent  life_exp     gdp_cap
# 1697  1977     6642107    Africa    57.674  685.587682
# 1698  1982     7636524    Africa    60.363  788.855041
# 1699  1987     9216418    Africa    62.351  706.157306
# 1700  1992    10704340    Africa    60.377  693.420786
# 1701  1997    11404948    Africa    46.809  792.449960
# 1702  2002    11926563    Africa    39.989  672.038623
# 1703  2007    12311143    Africa    43.487  469.709298
# 1704  2020     1234556      Asia    41.010  810.980000
# 1705  2020     1234556      Asia    41.010  810.980000

# %%
df.head()
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
# 2        2      3  Afghanistan  1962    10267083      Asia    31.997
# 3        3      4  Afghanistan  1967    11537966      Asia    34.020
# 4        4      5  Afghanistan  1972    13079460      Asia    36.088
#
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106

# %%
df.iloc[:2]
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
#
#       gdp_cap
# 0  779.445314
# 1  820.853030

# %%
users=pd.DataFrame({'user_id':[1,2,3],'Name':['Nimesh','Sindhu','Hema']})

# %%
users
# Out:
#    user_id    Name
# 0        1  Nimesh
# 1        2  Sindhu
# 2        3    Hema

# %%
msgs=pd.DataFrame({'user_id':[1,1,2,4],'messages':['hii','ha','oK K','hmm']})
msgs
# Out:
#    user_id messages
# 0        1      hii
# 1        1       ha
# 2        2     oK K
# 3        4      hmm

# %% [markdown]
# - Concat
# - Merge

# %%
pd.concat([users,msgs])
# Out:
#    user_id    Name messages
# 0        1  Nimesh      NaN
# 1        2  Sindhu      NaN
# 2        3    Hema      NaN
# 0        1     NaN      hii
# 1        1     NaN       ha
# 2        2     NaN     oK K
# 3        4     NaN      hmm

# %%
pd.concat([users,msgs],axis=1)
# Out:
#    user_id    Name  user_id messages
# 0      1.0  Nimesh        1      hii
# 1      2.0  Sindhu        1       ha
# 2      3.0    Hema        2     oK K
# 3      NaN     NaN        4      hmm

# %%
users.merge(msgs,how='inner')
# Out:
#    user_id    Name messages
# 0        1  Nimesh      hii
# 1        1  Nimesh       ha
# 2        2  Sindhu     oK K

# %%
users.merge(msgs,how='left')
# Out:
#    user_id    Name messages
# 0        1  Nimesh      hii
# 1        1  Nimesh       ha
# 2        2  Sindhu     oK K
# 3        3    Hema      NaN

# %%
users.merge(msgs,how='right')
# Out:
#    user_id    Name messages
# 0        1  Nimesh      hii
# 1        1  Nimesh       ha
# 2        2  Sindhu     oK K
# 3        4     NaN      hmm

# %%
users.merge(msgs,how='outer')
# Out:
#    user_id    Name messages
# 0        1  Nimesh      hii
# 1        1  Nimesh       ha
# 2        2  Sindhu     oK K
# 3        3    Hema      NaN
# 4        4     NaN      hmm

# %%
msgs
# Out:
#    user_id messages
# 0        1      hii
# 1        1       ha
# 2        2     oK K
# 3        4      hmm

# %%
msgs.rename({'user_id':'id'},axis=1,inplace=True)
msgs
# Out:
#    id messages
# 0   1      hii
# 1   1       ha
# 2   2     oK K
# 3   4      hmm

# %%
users.merge(msgs,left_on='user_id',right_on='id')
# Out:
#    user_id    Name  id messages
# 0        1  Nimesh   1      hii
# 1        1  Nimesh   1       ha
# 2        2  Sindhu   2     oK K

# %%
users.merge(msgs,left_on='user_id',right_on='id',how='left')
# Out:
#    user_id    Name   id messages
# 0        1  Nimesh  1.0      hii
# 1        1  Nimesh  1.0       ha
# 2        2  Sindhu  2.0     oK K
# 3        3    Hema  NaN      NaN

# %%
df.head()
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
# 2        2      3  Afghanistan  1962    10267083      Asia    31.997
# 3        3      4  Afghanistan  1967    11537966      Asia    34.020
# 4        4      5  Afghanistan  1972    13079460      Asia    36.088
#
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106

# %%
df.head()
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
# 2        2      3  Afghanistan  1962    10267083      Asia    31.997
# 3        3      4  Afghanistan  1967    11537966      Asia    34.020
# 4        4      5  Afghanistan  1972    13079460      Asia    36.088
#
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106

# %%
df['population'].sum()
# Out:
# 50442934913

# %%
df['population'].mean()
# Out:
# 29567957.158851113

# %%
df['population'].mode()
# Out:
# 0    1234556
# Name: population, dtype: int64

# %%
df['population'].min()
# Out:
# 60011

# %%
df.head()
# Out:
#    level_0  index      Country   yrs  population continent  life_exp  \
# 0        0      1  Afghanistan  1952     8425333      Asia    28.801
# 1        1      2  Afghanistan  1957     9240934      Asia    30.332
# 2        2      3  Afghanistan  1962    10267083      Asia    31.997
# 3        3      4  Afghanistan  1967    11537966      Asia    34.020
# 4        4      5  Afghanistan  1972    13079460      Asia    36.088
#
#       gdp_cap
# 0  779.445314
# 1  820.853030
# 2  853.100710
# 3  836.197138
# 4  739.981106

# %%
mean=df['life_exp'].mean()
mean
# Out:
# 59.45279289566237

# %%
df['Country'].nunique()
# Out:
# 142

# %%
#Question - In each continent how many unique countries are present which are having life expetency greater then mean life expectency

# %%
df1=df[df['life_exp']>mean]

# %%
df['Country'].value_counts()
# Out:
# Country
# India                14
# Afghanistan          12
# Nepal                12
# New Zealand          12
# Nicaragua            12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
df_asia=df[df['continent']=='Asia']
df_asia
# Out:
#       level_0  index      Country   yrs  population continent  life_exp  \
# 0           0      1  Afghanistan  1952     8425333      Asia    28.801
# 1           1      2  Afghanistan  1957     9240934      Asia    30.332
# 2           2      3  Afghanistan  1962    10267083      Asia    31.997
# 3           3      4  Afghanistan  1967    11537966      Asia    34.020
# 4           4      5  Afghanistan  1972    13079460      Asia    36.088
# ...       ...    ...          ...   ...         ...       ...       ...
# 1677     1677   1678  Yemen, Rep.  1997    15826497      Asia    58.020
# 1678     1678   1679  Yemen, Rep.  2002    18701257      Asia    60.308
# 1679     1679   1680  Yemen, Rep.  2007    22211743      Asia    62.698
# 1704     1704   1705        India  2020     1234556      Asia    41.010
# 1705     1705   1706        India  2020     1234556      Asia    41.010
#
#           gdp_cap
# 0      779.445314
# 1      820.853030
# 2      853.100710
# 3      836.197138
# ...

# %%
df_asia['Country'].nunique()
# Out:
# 33
