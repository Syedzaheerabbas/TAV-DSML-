# %%
0 and 1 #Reasech about this
# Out:
# 0

# %%
1 and 0
# Out:
# 0

# %%
1 and 10
# Out:
# 10

# %%
True and False
# Out:
# False

# %%
1 or 0
# Out:
# 1

# %%
29 and 0
# Out:
# 0

# %%
29 or 0
# Out:
# 29

# %%
0 or 1
# Out:
# 1

# %% [markdown]
# #Conditional statements

# %%
temp = int(input())
print( 'Temperature is ',temp)
# Out:
# 21
# Temperature is  21

# %%
Pin_number= int(input('Give me your pin number. It will be safe wit us' ))
print('Your Pin number is ',Pin_number)# This is a solution but why zero's aren't showing up. Try this input 0012.
print('Your Pin number is ','%04d'%Pin_number)
# Out:
# Give me your pin number. It will be safe wit us0012
# Your Pin number is  12
# Your Pin number is  0012

# %% [markdown]
#   - Home work
#    - Why zero's aren't showing up

# %%
temp = int(input('Enter the temperature outside '))
print('The temperature is',temp,'C')
if temp>=30:
  print('Wear a shirt. It is hot outside')
else:
  print('Wear a sweater. It is cold outside')
# Out:
# Enter the temperature outside -1
# The temperature is -1 C
# Wear a sweater. It is cold outside

# %%
#Take the time as input and greet(Only consider hours)
# 5-12 -Good Morning
# 13-15 Good Afternoon
# 16-19 Good evening
# 20-24 Good Night

# %%
time = int(input())
if time >= 5 and time <=12:
  print('Good Morning!')
elif time>=13 and time <=15:
  print('Good Afternoon')
elif time>=16 and time<=19:
  print('Good evening ')
else:
  print('Good Night')
# Out:
# 21
# Good Night

# %%
if 1!=1:
  print(1)
else :
  print(99)
  print(101)
print(102)
print(2)
print(3)
print(5)
print('a')
# Out:
# 99
# 101
# 102
# 2
# 3
# 5
# a

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(102)
print(14)
print('abc')
# Out:
# 102
# 14
# abc

# %% [markdown]
# #Quizes

# %% [markdown]
# ###Quiz 1
# What is the output of the following code?
# x = 5
# if x > 10:
# print("Hello")
# else:
# print("World")
# a. Hello
# b. World
# c. Error
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Quiz 2
#
# x = 0
# if x:
# print("True")
# else:
# print("False")
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Quiz 3
# x = 5
# if x > 2:
# if x < 10:
# print("x is between 2 and 10")
# else:
# print("x is greater than or equal to 10")
# else:
# print("x is less than or equal to 2")
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Quiz -4
# age = 15
# if age < 18:
# print("You are not eligible to vote")
# elif age >= 18 and age < 21:
# print("You can vote but can't drink")
# else:
# print("You can vote and drink")
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Question
#   - Take n as input and find whether its an even number or odd number

# %%
x = 5
if x > 10:
  print("Hello")
else:
  print("World")
# Out:
# World

# %%
x = 0
if x:
  print("True")
else:
  print("False")
# Out:
# False

# %%
x = 7*1/3
if x > 21:
  if x < 31:
    print("a")
  else:
    print("b")
else:
  print("c")
# Out:
# c

# %%
y=29//3+3-21
x =y+34-34
if x > 21:
  if x < 31:
    print("a")
  else:
    print("b")
else:
  print("c")
# Out:
# c

# %%
age = 15
if age < 18:
  print("You are not eligible to vote")
elif age >= 18 and age < 21:
  print("You can vote but can't drink")
else:
  print("You can vote and drink")
# Out:
# You are not eligible to vote
