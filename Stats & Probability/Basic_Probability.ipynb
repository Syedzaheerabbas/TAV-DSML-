# %%
import pandas as pd
import warnings

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7 -O Sachin_ODI.csv
# Out:
# --2025-02-06 10:26:44--  https://drive.google.com/uc?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7
# Resolving drive.google.com (drive.google.com)... 64.233.188.101, 64.233.188.102, 64.233.188.100, ...
# Connecting to drive.google.com (drive.google.com)|64.233.188.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7 [following]
# --2025-02-06 10:26:44--  https://drive.usercontent.google.com/download?id=1zBM3idCNWceBMLKMRBTN8aVFAg5U_YH7
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.174.132, 2404:6800:4008:c1b::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.174.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26440 (26K) [application/octet-stream]
# Saving to: ‘Sachin_ODI.csv’
#
# Sachin_ODI.csv      100%[===================>]  25.82K  --.-KB/s    in 0s
#
# ...

# %%
df=pd.read_csv('/content/Sachin_ODI.csv')

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
df.shape
# Out:
# (360, 14)

# %%
df['century'].value_counts()
# Out:
# century
# False    314
# True      46
# Name: count, dtype: int64

# %%
df['Won'].value_counts()
# Out:
# Won
# True     184
# False    176
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Q1. A match is randomly chosen, what is the probability that India have won that match?

# %%
 ans = df['Won'].value_counts()[0]/len(df) * 100
 print(f'In a randomly choosen match where sachin is playing, the probability of India wiining is = {ans}')
# Out:
# In a randomly choosen match where sachin is playing, the probability of India wiining is = 51.11111111111111

# %% [markdown]
# #Q2. A match is chosen at a random, what is the probability that Sachin has scored a Century in that match?

# %%
df.head()
# Out:
#    runs  NotOut mins  bf  fours  sixes      sr  Inns           Opp    Ground  \
# 0    13       0   30  15      3      0   86.66     1   New Zealand    Napier
# 1    37       0   75  51      3      1   72.54     2  South Africa  Hamilton
# 2    47       0   65  40      7      0  117.50     2     Australia   Dunedin
# 3    48       0   37  30      9      1  160.00     2    Bangladesh   Sharjah
# 4     4       0   13   9      1      0   44.44     2      Pakistan   Sharjah
#
#          Date        Winner    Won  century
# 0  1995-02-16   New Zealand  False    False
# 1  1995-02-18  South Africa  False    False
# 2  1995-02-22         India   True    False
# 3  1995-04-05         India   True    False
# 4  1995-04-07      Pakistan  False    False

# %%
 ans = df['century'].value_counts()[1]/len(df) * 100
print(f'In a randomly choosen match where  the probability of Sachin scoring a century is = {ans}')
# Out:
# In a randomly choosen match where  the probability of Sachin scoring a century is = 12.777777777777777

# %% [markdown]
# # Q3. A match is chosen at a random. What is the probability that Sachin has scored a century in that match and India have won that match?

# %%
data = pd.crosstab( index = df['century'],
                   columns = df['Won'],
                    margins = True)

# %%
pd.crosstab?

# %%
data
# Out:
# Won      False  True  All
# century
# False      160   154  314
# True        16    30   46
# All        176   184  360

# %%
30/360 *100
# Out:
# 8.333333333333332

# %% [markdown]
# #Conclusion

# %% [markdown]
# - P[Win] = 0.511
# - P[Century]
# = 0.127
# - P[Win and Century] = 0 083
#
# ![image.png](data:image/png;base64,...)
